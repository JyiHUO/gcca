# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
from utils import *
# Out:
# Using Theano backend.

# %%
data1 = load_data('noisymnist_view1.gz', 'https://www2.cs.uic.edu/~vnoroozi/noisy-mnist/noisymnist_view1.gz')
data2 = load_data('noisymnist_view2.gz', 'https://www2.cs.uic.edu/~vnoroozi/noisy-mnist/noisymnist_view2.gz')
# Out:
# loading data ...
# loading data ...

# %%
train1 = data1[0][0]

# %%
train1.shape
# Out:
# (50000, 784)

# %%
train2 = data2[0][0]

# %%
train2.shape
# Out:
# (50000, 784)

# %%
f, axarr = plt.subplots(4, 4, figsize = (10,10))
for i in range(4):
    for j in range(4):
        axarr[i, j].imshow(train1[i+j].reshape((28,28)), cmap = "gray")
        axarr[i, j].axis('off')

# %%
f, axarr = plt.subplots(4, 4, figsize = (10,10))
for i in range(4):
    for j in range(4):
        axarr[i, j].imshow(train2[i+j].reshape((28,28)), cmap = "gray")
        axarr[i, j].axis('off')

# %% [markdown]
# # svm baseline

# %%
x_train = data1[0][0]
y_train = data1[0][1]
x_test = data1[2][0]
y_test = data1[2][1]

# %%
from sklearn.svm import LinearSVC

# %%
clf = LinearSVC()

# %%
clf.fit(x_train, y_train)
# Out:
# LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0)

# %%
clf.score(x_test, y_test)
# Out:
# 0.8064
